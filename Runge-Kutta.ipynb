# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=y[0]-(y[0]**2)
    return F
"""providing initial values"""
x=0
xStop=5
h=0.1
y=np.array([1.5])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=y[0]
    return F
"""providing initial values"""
x=0
xStop=5
h=0.1
y=np.array([1.0])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=1-y[0]**2
    return F
"""providing initial values"""
x=0
xStop=5
h=0.1
y=np.array([0.0])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=1-4*y[0]*(1-y[0])
    return F
"""providing initial values"""
x=0
xStop=5
h=0.1
y=np.array([0]) #INITIAL VALUE
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=np.sin(y[0])
    return F
"""providing initial values"""
x=0
xStop=5
h=0.1
y=np.array([0.55])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=np.sin(x*y[0])
    return F
"""providing initial values"""
x=0
xStop=5
h=0.1
y=np.array([0.45])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=y[0]+np.exp(-y)
    return F
"""providing initial values"""
x=0
xStop=5
h=0.1
y=np.array([0.0])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=y[0]*(1-4*(y[0]-3)**2)
    return F
"""providing initial values"""
x=0
xStop=5
h=0.025
y=np.array([1.5])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=-4*y[0]*np.log(5*y[0])
    return F
"""providing initial values"""
x=1
xStop=5
h=0.1
y=np.array([10])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Ujjwaltd\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in log

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=np.zeros(2)
    F[0]=y[1]
    F[1]=y[0]+np.exp(x)
    return F
"""providing initial values"""
x=0
xStop=5
h=0.1
y=np.array([0.0,0.0])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=np.zeros(3)
    F[0]=y[1]
    F[1]=y[2]
    F[2]=np.exp(x*y[0]*y[1])
    return F
"""providing initial values"""
x=0
xStop=10
h=0.1
y=np.array([0.0,0.0,0.0])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()

# %%
"""RUNGE KUTTA FOURTH ORDER"""
import numpy as np
import matplotlib.pyplot as plt
def integrate(F,x,y,xStop,h):
    def run_kut4(F,x,y,h):
        k0=h*F(x,y)
        k1=h*F(x+h/2.0,y+k0/2.0)
        k2=h*F(x+h/2.0,y+k1/2.0)
        k3=h*F(x+h,y+k2)
        return(k0+2*(k1+k2)+k3)/6.0
        
    X=[]
    Y=[]
    
    while x<xStop:
         h=min(h,xStop-x)
         y=y+run_kut4(F,x,y,h)
         x=x+h
         X.append(x)
         Y.append(y)
    return np.array(X),np.array(Y)    
    
#now the only thing left is defining the function under consideration and initialisation values
"""function number 1"""
def F(x,y):
    F=np.zeros(3)
    F[0]=y[1]
    F[1]=y[2]
    F[2]=np.exp(x*y[0]*y[1]*y[2])
    return F
"""providing initial values"""
x=0
xStop=5
h=0.1
y=np.array([0.0,0.0,0.0])
X,Y = integrate(F,x,y,xStop,h)
"""now comes plotting"""
plt.plot(X,Y[:,0],'-')
plt.grid(True)
plt.show()
